# %%
config=[{
    "source":"crm",
    "path":"/Volumes/databricks_bootcamp/bronze/source_volume/source_crm/cust_info.csv",
    "table":"cust_info",

    "source":"crm",
    "path":"/Volumes/databricks_bootcamp/bronze/source_volume/source_crm/prd_info.csv",
    "table":"prd_info",

    "source":"crm",
    "path":"/Volumes/databricks_bootcamp/bronze/source_volume/source_crm/sales_details.csv",
    "table":"sales_details",

    "source":"erp",
    "path":"/Volumes/databricks_bootcamp/bronze/source_volume/source_erp/CUST_AZ12.csv",
    "table":"CUST_AZ12",

    "source":"erp",
    "path":"/Volumes/databricks_bootcamp/bronze/source_volume/source_erp/LOC_A101.csv",
    "table":"LOC_A101",

    "source":"erp",
    "path":"/Volumes/databricks_bootcamp/bronze/source_volume/source_erp/PX_CAT_G1V2.csv",
    "table":"PX_CAT_G1V2",
    
}]
