# %%
import pyspark.sql.functions as f
from pyspark.sql.types import StringType
from pyspark.sql.functions import trim, col

# %%
df=spark.table("databricks_bootcamp.bronze.px_cat_g1v2")

# %%
df.display()

# %%
rname={"ID":"proude_id",
       "CAT":"proude_categry",
       "SUBCAT":"proude_subcat",
       "MAINTENANCE":"proude_maintenance"}

for old_name,new_name in rname.items():
    df=df.withColumnRenamed(old_name,new_name)

# %%
df.display()

# %%
df = df.withColumn(
    "proude_maintenance",
    f.when(f.lower(col("proude_maintenance")) == "yes", "1")
     .when(f.lower(col("proude_maintenance")) == "no", "0")
     .otherwise("null")
)

# %%
df.display()

# %%
df.write.format("delta").mode("overwrite").saveAsTable("databricks_bootcamp.silver.proudects")
